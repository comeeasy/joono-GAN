# %% [markdown]
# # imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as dset
from torch.utils.data import DataLoader
import torch.backends.cudnn as cudnn
import matplotlib.pyplot as plt
from torchsummary import summary

from tqdm import tqdm
import os, sys
import numpy as np
import pandas as pd

from PIL import Image
from skimage import io

from models.Blocks import ConvBlock, TransposeConvBlock

cudnn.benchmark = True
device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # Hyperparameters

# %%
BATCH_SIZE = 64
DSET_ROOT = "data/img_align_celeba/"
CSV_ROOT = "data/img_align_celeba/list_attr_celeba.csv"
LR = 1e-4
EPOCHS = 10

# %% [markdown]
# # Custom dataset

# %%
class CelebA(torch.utils.data.Dataset):
    def __init__(self, root, csv_path, transforms=None):
        self.path = os.path.abspath(root)
        self.label = pd.read_csv(os.path.abspath(csv_path))
        self.transforms = transforms

    def __len__(self):
        return len(self.label)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_id = self.label.iloc[idx]["image_id"]
        img_path = os.path.abspath(os.path.join(self.path, "img_align_celeba", img_id))
        img = io.imread(img_path)

        is_male = self.label.iloc[idx]["Male"]
        is_male = 1 if is_male == 1 else 0
        is_male = np.array(is_male)
        is_male = is_male.astype('long')

        if self.transforms:
            img = self.transforms(img)

        return img, is_male

# %% [markdown]
# # Instantiate Dataloader

# %%
dataset = CelebA(
    root=DSET_ROOT, 
    csv_path=CSV_ROOT,
    transforms=transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize(256),
        transforms.CenterCrop(224),
    ])
)

data_loader = DataLoader(
    dataset=dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=8,
    pin_memory=True,
    drop_last=True
)

# %% [markdown]
# ## Visualize a few images

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# Get a batch of training data
inputs, classes = next(iter(data_loader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out)

# %% [markdown]
# # Train

# %% [markdown]
# ## model - pretrained resnet50

# %%
# model summary

model = torchvision.models.resnet18(pretrained=True)
model.fc = nn.Linear(in_features=512, out_features=2, bias=True)
summary(model, input_size=(3, 224, 224), device="cpu")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                    [-1, 2]           1,026
# ================================================================
# Total params: 11,177,538
# Trainable params: 11,177,538
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 42.64
# Estimated Total Size (MB): 106.00
# ----------------------------------------------------------------
# /home/r320/.local/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(params=model.parameters(), lr=LR)

# %%
for epoch in range(EPOCHS):
    best_loss = 1000
    for X, Y in tqdm(data_loader):
        X = X.to(device)
        Y = Y.to(device)

        predict = model(X)
        loss = criterion(predict, Y)
        
        model.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(f"epoch: {epoch + 1}\tloss: {loss:.4f}")
    if loss < best_loss:
        best_loss = loss
        torch.save(model.state_dict(), "models/best.pt")
# Out:
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:22<00:00,  9.43it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:22<00:00,  9.81it/s]
# epoch: 1	loss: 0.0094
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.79it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.75it/s]
# epoch: 2	loss: 0.0536
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.74it/s]
# epoch: 3	loss: 0.0198
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.93it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.74it/s]
# epoch: 4	loss: 0.0028
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.79it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.74it/s]
# epoch: 5	loss: 0.0180
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.93it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.74it/s]
# epoch: 6	loss: 0.0088
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.74it/s]
# epoch: 7	loss: 0.0566
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|█████████▉| 3164/3165 [05:24<00:00,  9.89it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.74it/s]
# epoch: 8	loss: 0.0025
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.36it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.74it/s]
# epoch: 9	loss: 0.0047
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.93it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# 100%|██████████| 3165/3165 [05:24<00:00,  9.74it/s]
# epoch: 10	loss: 0.0000

# %% [markdown]
# # Test

# %%
model_test = torchvision.models.resnet18(pretrained=False)
model_test.fc = nn.Linear(512, 2, bias=True)
model_test.load_state_dict(torch.load("models/best_7_12.pt"))
# Out:
# <All keys matched successfully>

# %%
model_test = model_test.to(device)
model_test.eval()

total_batch = len(data_loader)
accuracy = 0
with torch.no_grad():
    for X, Y in tqdm(data_loader):
        X = X.to(device)
        Y = Y.to(device)

        predict = model_test(X)
        predict = torch.argmax(predict, dim=1)
        accuracy += (predict == Y).float().mean().item() / total_batch

print(f"accuracy: {100 * accuracy:.2f}%")
# Out:
#   0%|          | 0/3165 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
#   1%|▏         | 42/3165 [00:02<02:58, 17.47it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>
#
# Traceback (most recent call last):
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
# Traceback (most recent call last):
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
# self._shutdown_workers()        if w.is_alive():
#
# Exception ignored in:   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>    assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorif w.is_alive()::
# can only test a child processTraceback (most recent call last):
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#
#       File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#   1%|▏         | 44/3165 [00:03<03:22, 15.45it/s]only test a child process'Exception ignored in: self._shutdown_workers()
#
# AssertionError<function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>
# : Traceback (most recent call last):
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
# can only test a child processException ignored in: Exception ignored in:   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>    <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>if w.is_alive():
#
# Traceback (most recent call last):
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#
# self._shutdown_workers()self._shutdown_workers()  File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
#
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#       File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
# if w.is_alive():
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
# Traceback (most recent call last):
# Exception ignored in: assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError    : <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>AssertionErrorcan only test a child process: if w.is_alive():  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#
#
# Traceback (most recent call last):
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# can only test a child process
#
# self._shutdown_workers()
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#   1%|▏         | 47/3165 [00:03<02:57, 17.59it/s]assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#
#         if w.is_alive():self._shutdown_workers()AssertionError
# : Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#         if w.is_alive():can only test a child processTraceback (most recent call last):
# Exception ignored in:
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# AssertionError:
# Exception ignored in: Traceback (most recent call last):
#         can only test a child processassert self._parent_pid == os.getpid(), 'can only test a child process'self._shutdown_workers()
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#
#
#
#     if w.is_alive():Exception ignored in:
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
# AssertionError<function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>
# self._shutdown_workers()Traceback (most recent call last):
# Traceback (most recent call last):
#
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
# :     can only test a child processif w.is_alive():
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#       File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'        assert self._parent_pid == os.getpid(), 'can only test a child process'self._shutdown_workers()
#
#     self._shutdown_workers()
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
# Exception ignored in:
# AssertionError<function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>Exception ignored in: : AssertionErrorcan only test a child process
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
# :
# can only test a child process
#
# if w.is_alive():Traceback (most recent call last):
#     if w.is_alive():
#
# Traceback (most recent call last):
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>  File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#       File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#
#     Traceback (most recent call last):
# assert self._parent_pid == os.getpid(), 'can only test a child process'self._shutdown_workers()
# self._shutdown_workers()  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#         if w.is_alive():
# AssertionErrorassert self._parent_pid == os.getpid(), 'can only test a child process':
# self._shutdown_workers()if w.is_alive():can only test a child processAssertionError:
#
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#
#
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():  File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     can only test a child processassert self._parent_pid == os.getpid(), 'can only test a child process'
#
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#
# AssertionErrorException ignored in: : AssertionError<function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>AssertionError: :
# Traceback (most recent call last):
# can only test a child processcan only test a child processcan only test a child process  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#
#
#     self._shutdown_workers()
#
#   File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb8d74179d0>Exception ignored in:
# Traceback (most recent call last):
#       File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
# assert self._parent_pid == os.getpid(), 'can only test a child process'    self._shutdown_workers()
#
# AssertionError  File "/home/r320/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
# :     can only test a child processif w.is_alive():
#   File "/home/r320/anaconda3/envs/vonenet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#
# 100%|██████████| 3165/3165 [03:01<00:00, 17.48it/s]
# accuracy: 99.91%
